# %%
import requests
from bs4 import BeautifulSoup

def scrape_text(url):
    try:
        # Fetch the webpage content
        response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
        response.raise_for_status()  # Raise an error for bad responses

        # Parse the HTML content
        soup = BeautifulSoup(response.text, "html.parser")

        # Extract and clean up text
        text = soup.get_text(separator="\n", strip=True)
        return text

    except requests.exceptions.RequestException as e:
        return f"Error fetching page: {e}"

# Example usage
url = "https://www.dmv.virginia.gov/vehicles/registration/tow-truck-reg"  # Replace with the actual URL
scraped_text = scrape_text(url)
print(scraped_text)  # Print first 500 characters for preview
# Out:
# Register a Tow Truck in Virginia | Virginia Department of Motor Vehicles
# Skip to main content
# Virginia Department of Motor Vehicles
# Utility menu
# Online Services
# Locations
# Moving
# Forms
# My Account
# Search
# Search Site
# Submit
# Main menu
# Licenses & IDs
# Licenses & IDs
# Driver's License
# REAL ID
# Learner's Permits
# ID Cards
# Commercial Driver's Licenses
# Motorcycle License
# Exams & Study Materials
# Driver Training
# Driver Improvement
# Disability Programs
# Payment Plan Program
# Organ Donation
# License Extension
# Military Personnel
# Moving
# Document Guide
# Know which documents are required for your driver application before you head to DMV.
# Access Guide
# Vehicles
# Vehicles
# Title Your Vehicle or Trailer
# Registration
# First Time Vehicle Registration
# Trailer Registration
# Emissions Inspections
# Delinquent Property Taxes and Vehicle Registration
# Electric Vehicles
# Antique Motor Vehicles and Trailers
# Trip Permit
# Denial of Registrations or Renewal
# Receive Notifications - Email and Text Reminders
# eNotification Policy
# Renew Your Vehicle Registration by Mail
# Farm Vehicles
# All About Mopeds
# Register a Tow Truck in Virginia
# State-Owned Vehicles
# Local Vehicle Registration Program
# Military Surplus Motor Vehicles
# City of Virginia Beach: Vehicle Registration Fees
# City of Virginia Beach: Vehicle Registration Exemptions and Discounts
# Sample Registration Card
# Submitting Registration-Only Applications by Mail
# Vehicle Color Codes for Virginia
# License Plates
# Buying/Selling a Vehicle
# Insurance Coverage Verification
# Taxes & Fees
# E-ZPass at DMV
# Insurance Requirements
# General Information
# National Motor Vehicle Titling Information System (NMVTIS)
# Abandoned Vehicles/ Mechanics & Storage Lien (MSL) Vehicles
# Download Vehicle Forms
# Registration Renewal
# Renew your vehicle registration before it expires to avoid a late fee.
# Renew Registration
# Businesses
# Businesses
# Motor Carriers
# Hauling Permits
# Insurance Services
# Electronic Lien Program
# Virginia Motor Fuels Tax Programs
# Business Opportunities
# How to Become a DMV Select Partner
# Online Fleet
# Dealer Services
# Online Dealers
# Rental Tax
# Transportation Network Companies (TNC)
# VirginiaMCS
# Access VirginiaMCS to conduct your Virginia IRP and/or IFTA transactions online.
# Access VirginiaMCS
# Records
# Records
# Driver Alert Voluntary Driving Record Monitoring Program
# Request a Copy of Your Driver or Vehicle Record
# Request a Police Crash Report from DMV
# Obtain Vehicle History
# Change Address, Name or Sex Designation
# Non-Governmental Access to DMV Records
# Governmental Access to DMV Records
# Resources for Family of Deceased
# Emergency Contact Information
# Vital Records at DMV
# Prospective Purchaser Inquiry (PPI)
# Release of DMV Information
# Freedom of Information Act (FOIA) Rights and Responsibilities
# Register to Vote
# Driving & Vehicle Records
# Purchase a copy of your driver or vehicle record online.
# View Records
# Safety
# Safety
# Statewide Crash Data
# Grants Management
# Safety Programs
# Safety Resources
# Points Balance
# Check your points balance to see where your record stands.
# Check Balance
# Reserve Your Spot
# Breadcrumb
# Home
# Vehicles
# Registration
# Register a Tow Truck in Virginia
# Skip to main content
# Registration
# First Time Vehicle Registration
# Trailer Registration
# Emissions Inspections
# Delinquent Property Taxes and Vehicle Registration
# Electric Vehicles
# Antique Motor Vehicles and Trailers
# Trip Permit
# Denial of Registrations or Renewal
# Receive Notifications - Email and Text Reminders
# eNotification Policy
# Renew Your Vehicle Registration by Mail
# Farm Vehicles
# All About Mopeds
# Register a Tow Truck in Virginia
# State-Owned Vehicles
# Local Vehicle Registration Program
# Military Surplus Motor Vehicles
# City of Virginia Beach: Vehicle Registration Fees
# City of Virginia Beach: Vehicle Registration Exemptions and Discounts
# Sample Registration Card
# Submitting Registration-Only Applications by Mail
# Vehicle Color Codes for Virginia
# For a smooth registration process, it’s helpful to start with a few terms.
# Tow Truck
# A for-hire motor vehicle designed to lift, pull or carry another vehicle by means of a hoist or other mechanical apparatus. This includes vehicles designed with a ramp on wheels and a hydraulic lift with a capacity to haul or tow another vehicle, commonly referred to as “flatbeds” or "rollbacks."
# A vehicle designed with a ramp on wheels and a hydraulic lift with a capacity to haul or tow another vehicle, commonly referred to as a "rollback" is also classified as a tow truck.
# Note: Automobile or watercraft transporters, stinger-steered automobile or watercraft transporters, and tractor trucks are not considered tow trucks.
# Wrecker
# A motor vehicle that is eligible to be registered as a tow truck, but will only be used in a private capacity. Essentially, a private use tow truck.
# For-Hire
# A motor vehicle designed for transportation of property, and used for such by the owner or lessee, for compensation.
# Private Use
# A motor vehicle designed for the transportation of property, operated as such by the owner or lessee for their convenience, not for compensation.
# Intrastate Operation
# When a vehicle is operated solely within one state.
# Interstate Operation
# When a vehicle is operated across state lines.
# International Registration Plan (IRP)
# An international agreement under which a carrier's base state or Canadian province collects vehicle registration fees for other states/provinces based on the percentage of miles a fleet operates in the various jurisdictions. See
# International Registration Plan
# for details.
# Registration Options
# The registration process will differ depending on whether you’ll use the tow truck for:
# Private use
# For-hire
# Intrastate
# Interstate
# Private Use
# If you’re operating a tow truck for private use (a wrecker), regardless of weight, you must register it as:
# Vehicle Use:
# Private
# Body Type:
# Truck
# License Plate Type:
# Truck
# For Hire
# If you’re operating a tow truck for hire and it is
# under 10,000 pounds
# , you must register it as:
# Vehicle Use:
# For Hire
# Body Type:
# Truck
# License Plate Type:
# Truck
# If you’re operating a tow truck for hire and it is
# 10,000 pounds or greater
# , you must register it as:
# Vehicle Use:
# For Hire
# Body Type:
# Tow Truck
# License Plate Type:
# Tow Truck
# Intrastate
# If you’re operating a for hire or private use tow truck solely within Virginia, follow the above requirements.
# Interstate
# If you’re operating a for-hire or private use tow truck across state lines and it is under 10,000 pounds, follow the above requirements.
# If you’re operating a for-hire or private use tow truck across state lines and it is
# at least 10,000 pounds
# , in addition to the above requirements, you will need a DOT number. You may also need a DOT in some other circumstances. See
# Do I Need a DOT Number?
# for specific requirements.
# If you’re operating a for-hire or private use tow truck across state lines and it is
# over 26,000 pounds
# , you must register it with
# IRP apportioned license plates
# .
# IRP Exemption
# Some for-hire tow trucks may be exempt from IRP registration. DMV issues a “tow truck” license plate regardless of the “type” of tow truck, and considers this plate a “restricted license plate.”
# However, some states don’t allow certain types of tow trucks to travel with restricted tow truck plates, and you may be subject to a ticket or citation.
# Visit the
# IRP jurisdiction page
# or contact the DMV of each jurisdiction you plan to travel into or through to determine if they will allow travel with tow truck plates.
# Still Have Questions?
# Tow Truck/Wrecker Registration, Intrastate or Interstate
# Find plate options, registration, fees and insurance requirements.
# Document
# How to Register
# To register a tow truck in Virginia, submit the following to DMV:
# Proof of insurance coverage. See
# Tow Trucks and Wreckers Registration Options
# for requirements.
# If you have a Virginia title and it’s in your possession: a completed
# Application for Registration
# .
# Otherwise, a completed
# Application for Certificate of Title and Registration
# .
# If titling the vehicle, submit proof of address. See our
# Document Guide
# to determine which documents are acceptable.
# If the tow truck is operated
# For-Hire
# :
# You will not be able to get vehicle registration unless DMV has issued you Operating Authority. To be issued Operating Authority, you must:
# Submit a completed
# For-Hire Intrastate Operating Authority Permit Application
# to the Motor Carrier Services department at DMV headquarters.
# Your insurance carrier must file a Form E certificate of insurance with DMV confirming liability coverage for the tow truck you are registering.
# If you are attempting to register your tow truck with an Operating Authority under a name different than the name(s) being used to register the tow truck, you must complete the
# For-Hire Vehicles Registration Request
# and
# Motor Carrier Motor Vehicle Lease Agreement
# and submit this form to the Motor Carrier Services department at DMV headquarters.
# Motor Carrier Services will let you know by the next business day whether you’ve received pre-authorization to complete the vehicle registration transaction, or if there are other items you must still provide.
# Submit the appropriate
# fees
# .
# Apply With Confidence
# View
# Registration Options
# to compare the different ways of registering tow trucks.
# About Us
# Through our mission purpose, the DMV aims to be Virginia's most trusted service provider.
# About DMV
# Careers
# Procurement
# Resources
# Online Services
# How Do I?
# Forms
# News
# Policies & Regulations
# Fee Chart
# ¿Habla Español?
# Contact
# Locations
# Contact Us
# Media
# Stay Connected
# Facebook
# Instagram
# LinkedIn
# Twitter
# Youtube
# Virginia Department of Motor Vehicles (Superior Service | Secure Credentials | Saving Lives)
# ©2025
#             Virginia Department of Motor Vehicles. All Rights Reserved.
# Privacy Policy.
# Back to top

# %%
import requests
from bs4 import BeautifulSoup

# URL to scrape
url = "https://www.dmv.virginia.gov/vehicles/registration/tow-truck-reg"  # Replace with your actual URL

# Fetch the webpage
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    soup = BeautifulSoup(response.text, 'html.parser')

    # Find all accordion items
    accordion_items = soup.select('.c-accordion-item')

    # Loop through each accordion item
    for item in accordion_items:
        # Extract the button text (heading)
        button = item.select_one('.c-accordion-item__toggle')
        button_text = button.get_text(strip=True) if button else "Not found"

        # Extract the description inside the first paragraph in drawer-inner
        drawer_inner = item.select_one('.c-accordion-item__drawer-inner p')
        description_text = drawer_inner.get_text(strip=True) if drawer_inner else "Not found"

        # Print results for each accordion item
        print(f"Heading: {button_text}")
        print(f"Description: {description_text}")
        print("-" * 50)

else:
    print(f"Failed to retrieve the page. Status code: {response.status_code}")
# Out:
# Heading: Tow Truck
# Description: A for-hire motor vehicle designed to lift, pull or carry another vehicle by means of a hoist or other mechanical apparatus. This includes vehicles designed with a ramp on wheels and a hydraulic lift with a capacity to haul or tow another vehicle, commonly referred to as “flatbeds” or "rollbacks."
# --------------------------------------------------
# Heading: Wrecker
# Description: A motor vehicle that is eligible to be registered as a tow truck, but will only be used in a private capacity. Essentially, a private use tow truck.
# --------------------------------------------------
# Heading: For-Hire
# Description: A motor vehicle designed for transportation of property, and used for such by the owner or lessee, for compensation.
# --------------------------------------------------
# Heading: Private Use
# Description: A motor vehicle designed for the transportation of property, operated as such by the owner or lessee for their convenience, not for compensation.
# --------------------------------------------------
# Heading: Intrastate Operation
# Description: When a vehicle is operated solely within one state.
# --------------------------------------------------
# Heading: Interstate Operation
# Description: When a vehicle is operated across state lines.
# --------------------------------------------------
# Heading: International Registration Plan (IRP)
# Description: An international agreement under which a carrier's base state or Canadian province collects vehicle registration fees for other states/provinces based on the percentage of miles a fleet operates in the various jurisdictions. SeeInternational Registration Planfor details.
# --------------------------------------------------
# Heading: Private Use
# Description: If you’re operating a tow truck for private use (a wrecker), regardless of weight, you must register it as:
# --------------------------------------------------
# Heading: For Hire
# Description: If you’re operating a tow truck for hire and it isunder 10,000 pounds, you must register it as:
# --------------------------------------------------
# Heading: Intrastate
# Description: If you’re operating a for hire or private use tow truck solely within Virginia, follow the above requirements.
# --------------------------------------------------
# Heading: Interstate
# Description: If you’re operating a for-hire or private use tow truck across state lines and it is under 10,000 pounds, follow the above requirements.
# --------------------------------------------------

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urlparse
from pathlib import Path

# Base output directory
OUTPUT_DIR = 'dmv_site_data_v2'

def get_path_components(url, base_url):
    """Extract path components from URL after removing base_url"""
    relative_path = url.replace(base_url, '')
    components = [comp for comp in relative_path.strip('/').split('/') if comp]
    return components

def create_nested_directory(url, base_url):
    """Create nested directory structure based on URL path"""
    components = get_path_components(url, base_url)
    
    if len(components) >= 2:
        dir_path = os.path.join(OUTPUT_DIR, components[0], components[1])
    else:
        dir_path = os.path.join(OUTPUT_DIR, 'root')
    
    os.makedirs(dir_path, exist_ok=True)
    return dir_path

def get_safe_filename(url, base_url):
    """Convert last part of URL path to safe filename"""
    components = get_path_components(url, base_url)
    filename = components[-1] if components else 'index'
    return f"{filename}.json"

def fetch_page(url):
    response = requests.get(url)
    return BeautifulSoup(response.text, 'html.parser') if response.status_code == 200 else None

def extract_all_text(soup):
    main_contents = soup.find_all('div', class_='c-wysiwyg')
    return "\n\n".join(content.get_text(separator='\n', strip=True) for content in main_contents) if main_contents else "No content found"


def extract_accordions(soup):
    """Extract accordion items with headings and descriptions"""
    accordions = []
    for item in soup.select('.c-accordion-item'):
        button = item.select_one('.c-accordion-item__toggle')
        button_text = button.get_text(strip=True) if button else "Not found"
        
        drawer_inner = item.select_one('.c-accordion-item__drawer-inner p')
        description = drawer_inner.get_text(strip=True) if drawer_inner else "Not found"
        
        accordions.append({
            'heading': button_text,
            'description': description
        })
    return accordions

def extract_submenu_links(soup):
    submenu_links = {}
    for submenu in soup.select('.c-menu__subnav .c-menu__item a'):
        title = submenu.get_text(strip=True)
        url = submenu.get('href')
        if url and title:
            submenu_links[title] = url
    return submenu_links

def extract_attachments(soup, base_url, dir_path):
    attachments = {}
    attachments_dir = os.path.join(dir_path, 'attachments')
    os.makedirs(attachments_dir, exist_ok=True)

    for link in soup.find_all('a', href=True):
        file_url = link['href']
        if not file_url.startswith('http'):
            file_url = f"{base_url}{file_url}"
        
        if file_url.endswith(('.pdf', '.doc', '.docx', '.xls', '.xlsx')):
            file_name = os.path.basename(file_url)
            file_path = os.path.join(attachments_dir, file_name)
            
            try:
                response = requests.get(file_url, stream=True)
                if response.status_code == 200:
                    with open(file_path, 'wb') as f:
                        for chunk in response.iter_content(1024):
                            f.write(chunk)
                    attachments[file_name] = os.path.join('attachments', file_name)
            except Exception as e:
                print(f"Failed to download {file_url}: {e}")
    return attachments

def save_page_data(data, url, base_url):
    """Save page data to a JSON file in the appropriate nested directory"""
    dir_path = create_nested_directory(url, base_url)
    filename = get_safe_filename(url, base_url)
    filepath = os.path.join(dir_path, filename)
    
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)
    
    print(f"Saved data to {filepath}")
    return dir_path

def main():
    base_url = "https://www.dmv.virginia.gov"
    start_url = f"{base_url}/vehicles/registration/first-reg"
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    soup = fetch_page(start_url)
    if not soup:
        return
    
    # Process main page
    dir_path = create_nested_directory(start_url, base_url)
    main_page_data = {
        "url": start_url,
        "text_content": extract_all_text(soup),
        "accordions": extract_accordions(soup),
        "attachments": extract_attachments(soup, base_url, dir_path)
    }
    save_page_data(main_page_data, start_url, base_url)
    
    # Process submenu pages
    submenu_links = extract_submenu_links(soup)
    for title, relative_url in submenu_links.items():
        full_url = f"{base_url}{relative_url}"
        submenu_soup = fetch_page(full_url)
        
        if submenu_soup:
            dir_path = create_nested_directory(full_url, base_url)
            submenu_data = {
                "url": full_url,
                "title": title,
                "text_content": extract_all_text(submenu_soup),
                "accordions": extract_accordions(submenu_soup),
                "attachments": extract_attachments(submenu_soup, base_url, dir_path)
            }
            save_page_data(submenu_data, full_url, base_url)

if __name__ == "__main__":
    main()
# Out:
# Saved data to dmv_site_data_v2\vehicles\registration\first-reg.json
# Saved data to dmv_site_data_v2\vehicles\registration\first-reg.json
# Saved data to dmv_site_data_v2\vehicles\registration\trailer.json
# Saved data to dmv_site_data_v2\vehicles\registration\emissions.json
# Saved data to dmv_site_data_v2\vehicles\registration\stop-register.json
# Saved data to dmv_site_data_v2\vehicles\registration\alternative-vehicles.json
# Saved data to dmv_site_data_v2\vehicles\registration\antique.json
# Saved data to dmv_site_data_v2\vehicles\registration\temp-permit.json
# Saved data to dmv_site_data_v2\vehicles\registration\denials.json
# Saved data to dmv_site_data_v2\vehicles\registration\enotification-info.json
# Saved data to dmv_site_data_v2\vehicles\registration\enotification-policy.json
# Saved data to dmv_site_data_v2\vehicles\registration\mail-renew.json
# Saved data to dmv_site_data_v2\vehicles\registration\farm.json
# Saved data to dmv_site_data_v2\vehicles\registration\moped.json
# Saved data to dmv_site_data_v2\vehicles\registration\tow-truck-reg.json
# Saved data to dmv_site_data_v2\vehicles\registration\state-owned-vehicles.json
# Saved data to dmv_site_data_v2\vehicles\registration\lvrp.json
# Saved data to dmv_site_data_v2\vehicles\registration\surplus.json
# Saved data to dmv_site_data_v2\vehicles\registration\exemp-disc-chart.json
# Saved data to dmv_site_data_v2\root\exemp-disc-chart.json
# Saved data to dmv_site_data_v2\vehicles\registration\sample-card.json
# Saved data to dmv_site_data_v2\vehicles\registration\title-mail-reg-only.json
# Saved data to dmv_site_data_v2\vehicles\registration\color-codes.json

# %%
import os
import requests
from bs4 import BeautifulSoup
import json
from urllib.parse import urlparse
from pathlib import Path

# Base output directory
OUTPUT_DIR = 'dmv_site_data_base'

def get_path_components(url, base_url):
    """Extract path components from URL after removing base_url"""
    relative_path = url.replace(base_url, '')
    components = [comp for comp in relative_path.strip('/').split('/') if comp]
    return components

def create_nested_directory(url, base_url):
    """Create nested directory structure based on URL path"""
    components = get_path_components(url, base_url)
    
    if len(components) >= 2:
        dir_path = os.path.join(OUTPUT_DIR, components[0], components[1])
    else:
        dir_path = os.path.join(OUTPUT_DIR, 'root')
    
    os.makedirs(dir_path, exist_ok=True)
    return dir_path

def get_safe_filename(url, base_url):
    """Convert last part of URL path to safe filename"""
    components = get_path_components(url, base_url)
    filename = components[-1] if components else 'index'
    return f"{filename}.json"

def fetch_page(url):
    response = requests.get(url)
    return BeautifulSoup(response.text, 'html.parser') if response.status_code == 200 else None

def extract_submenu_links(soup):
    submenu_links = {}
    for submenu in soup.select('.c-menu__subnav .c-menu__item a'):
        title = submenu.get_text(strip=True)
        url = submenu.get('href')
        if url and title:
            submenu_links[title] = url
    return submenu_links

def extract_attachments(soup, base_url, dir_path):
    attachments = {}
    attachments_dir = os.path.join(dir_path, 'attachments')
    os.makedirs(attachments_dir, exist_ok=True)

    for link in soup.find_all('a', href=True):
        file_url = link['href']
        if not file_url.startswith('http'):
            file_url = f"{base_url}{file_url}"
        
        if file_url.endswith(('.pdf', '.doc', '.docx', '.xls', '.xlsx')):
            file_name = os.path.basename(file_url)
            file_path = os.path.join(attachments_dir, file_name)
            
            try:
                response = requests.get(file_url, stream=True)
                if response.status_code == 200:
                    with open(file_path, 'wb') as f:
                        for chunk in response.iter_content(1024):
                            f.write(chunk)
                    attachments[file_name] = os.path.join('attachments', file_name)
            except Exception as e:
                print(f"Failed to download {file_url}: {e}")
    return attachments

def save_page_data(data, url, base_url, custom_filename=None):
    """Save page data to a JSON file with optional custom filename"""
    dir_path = create_nested_directory(url, base_url)
    filename = custom_filename if custom_filename else get_safe_filename(url, base_url)
    filepath = os.path.join(dir_path, filename)
    
    with open(filepath, 'w', encoding='utf-8') as f:
        json.dump(data, f, indent=4)
    
    print(f"Saved data to {filepath}")
    return dir_path

def extract_all_text(soup):
    """Extract and combine all text content with formatted accordions"""
    main_content = []
    accordion_content = []
    
    # Extract main content blocks
    for content in soup.find_all('div', class_='c-wysiwyg'):
        main_content.append(content.get_text(separator='\n', strip=True))
    
    # Extract and format accordions
    for item in soup.select('.c-accordion-item'):
        heading = item.select_one('.c-accordion-item__toggle')
        description = item.select_one('.c-accordion-item__drawer-inner p')
        
        if heading and description:
            accordion_text = f"{heading.get_text(strip=True)}\n{description.get_text(strip=True)}"
            accordion_content.append(accordion_text)
    
    # Combine each section separately and then join them
    parts = []
    if main_content:
        parts.append("\n".join(main_content))
    if accordion_content:
        parts.append("\n".join(accordion_content))
    
    return "\n\n".join(parts) if parts else "No content found"

def main():
    base_url = "https://www.dmv.virginia.gov"
    homepage_url = f"{base_url}/safety/programs"
    start_url = f"{homepage_url}/bicycle-safety" #put homepage here if there's no subpages
    
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    
    # Process homepage
    homepage_soup = fetch_page(homepage_url)
    if homepage_soup:
        homepage_data = {
            "url": homepage_url,
            "text_content": extract_all_text(homepage_soup),
            "attachments": extract_attachments(homepage_soup, base_url, 
                create_nested_directory(homepage_url, base_url))
        }
        save_page_data(homepage_data, homepage_url, base_url, "homepage.json")
    
    # Process main registration page
    soup = fetch_page(start_url)
    if not soup:
        return
    
    main_page_data = {
        "url": start_url,
        "text_content": extract_all_text(soup),
        "attachments": extract_attachments(soup, base_url, 
            create_nested_directory(start_url, base_url))
    }
    save_page_data(main_page_data, start_url, base_url)
    
    # Process submenu pages
    submenu_links = extract_submenu_links(soup)
    for title, relative_url in submenu_links.items():
        full_url = f"{base_url}{relative_url}"
        submenu_soup = fetch_page(full_url)
        
        if submenu_soup:
            submenu_data = {
                "url": full_url,
                "title": title,
                "text_content": extract_all_text(submenu_soup),
                "attachments": extract_attachments(submenu_soup, base_url, 
                    create_nested_directory(full_url, base_url))
            }
            save_page_data(submenu_data, full_url, base_url)

if __name__ == "__main__":
    main()

# %%
import json
import os
from pathlib import Path

def add_page_field_to_json(root_dir):
    """
    Recursively processes all JSON files in directory and adds 'page' field
    with the relative path from the root directory
    """
    root_path = Path(root_dir)
    
    for json_path in root_path.rglob('*.json'):
        try:
            # Get relative path first
            relative_path = json_path.relative_to(root_path)
            
            with open(json_path, 'r+', encoding='utf-8') as f:  # r+ mode for read/write
                data = json.load(f)
                
                # Add page field if it doesn't exist
                if 'page' not in data:
                    data['page'] = str(relative_path)
                    
                    # Write back to file
                    f.seek(0)  # Reset file pointer
                    json.dump(data, f, indent=4)
                    f.truncate()  # Remove remaining content if new data is shorter
                    
                    print(f"Updated {relative_path}")
                else:
                    print(f"Skipped {relative_path} (already has page field)")
                    
        except json.JSONDecodeError:
            print(f"Error decoding JSON in {relative_path}")
        except Exception as e:
            print(f"Error processing {relative_path}: {str(e)}")


directory = r"C:\Users\benja\startup_projects\civgen\rag\dmv_site_data_base"  # CHANGE THIS TO YOUR PATH
    
if not Path(directory).exists():
    print(f"Error: Directory {directory} does not exist")
    exit(1)
    
print(f"Processing JSON files in {directory}...")
add_page_field_to_json(directory)
print("Operation completed")
# Out:
# Processing JSON files in C:\Users\benja\startup_projects\civgen\rag\dmv_site_data_base...
# Updated root\exemp-disc-chart.json
# Updated root\homepage.json
# Updated root\vrtp.json
# Updated businesses\become-dmv-select\homepage.json
# Updated businesses\dealer-services\car-and-truck-filing-fees-and-plate-requirements.json
# Updated businesses\dealer-services\franchise-motorcycle.json
# Updated businesses\dealer-services\franchise-trailer.json
# Updated businesses\dealer-services\homepage.json
# Updated businesses\dealer-services\licensing.json
# Updated businesses\dealer-services\mnfdist.json
# Updated businesses\dealer-services\motor-home-and-travel-trailer-filing-franchises.json
# Updated businesses\dealer-services\salvage-process-a.json
# Updated businesses\dealer-services\salvage-process-b.json
# Updated businesses\dealer-services\salvage-process-d.json
# Updated businesses\hauling\blanket.json
# Updated businesses\hauling\free.json
# Updated businesses\hauling\homepage.json
# Updated businesses\insurance\acknowledge.json
# Updated businesses\insurance\certifications.json
# Updated businesses\insurance\ext-forms.json
# Updated businesses\insurance\frrequire.json
# Updated businesses\insurance\general-info.json
# Updated businesses\insurance\homepage.json
# Updated businesses\insurance\intro.json
# Updated businesses\insurance\laws.json
# Updated businesses\insurance\mcs-filing.json
# Updated businesses\insurance\monitoring-methods.json
# Updated businesses\insurance\online.json
# Updated businesses\insurance\penalties.json
# Updated businesses\lien\convert-electronic.json
# Updated businesses\lien\electronic-lien-lienholder-codes-participants.json
# Updated businesses\lien\faqs.json
# Updated businesses\lien\homepage.json
# Updated businesses\lien\how-join.json
# Updated businesses\lien\overview.json
# Updated businesses\lien\process.json
# Updated businesses\lien\sample.json
# Updated businesses\lien\tech-specs.json
# Updated businesses\lien\testing.json
# Updated businesses\lien\who-contact.json
# Updated businesses\motor-carriers\auth-mc.json
# Updated businesses\motor-carriers\choosing-limo.json
# Updated businesses\motor-carriers\citations.json
# Updated businesses\motor-carriers\closing-checklist.json
# Updated businesses\motor-carriers\contactmcs.json
# Updated businesses\motor-carriers\escort-dr-cert.json
# Updated businesses\motor-carriers\ezfleet.json
# Updated businesses\motor-carriers\faqs.json
# Updated businesses\motor-carriers\fee-chart.json
# Updated businesses\motor-carriers\forms.json
# Updated businesses\motor-carriers\hauling-forms.json
# Updated businesses\motor-carriers\homepage.json
# Updated businesses\motor-carriers\hvut.json
# Updated businesses\motor-carriers\ifta.json
# Updated businesses\motor-carriers\intrastate.json
# Updated businesses\motor-carriers\irp.json
# Updated businesses\motor-carriers\links.json
# Updated businesses\motor-carriers\overload.json
# Updated businesses\motor-carriers\portal.json
# Updated businesses\motor-carriers\trip-permits.json
# Updated businesses\motor-carriers\ucra.json
# Updated businesses\motor-carriers\usdot.json
# Updated businesses\motor-carriers\va-mcs-signup.json
# Updated businesses\motor-carriers\va-mcs.json
# Updated businesses\motor-carriers\weigh.json
# Updated businesses\odealer\contacts.json
# Updated businesses\odealer\homepage.json
# Updated businesses\online-fleet\ezreg.json
# Updated businesses\online-salvage\homepage.json
# Updated businesses\opportunities\homepage.json
# Updated businesses\tax-act\bond.json
# Updated businesses\tax-act\discounts.json
# Updated businesses\tax-act\diversions.json
# Updated businesses\tax-act\drive-aways.json
# Updated businesses\tax-act\faqs.json
# Updated businesses\tax-act\fuels.json
# Updated businesses\tax-act\gge.json
# Updated businesses\tax-act\historical-rates.json
# Updated businesses\tax-act\homepage.json
# Updated businesses\tax-act\info-news.json
# Updated businesses\tax-act\library-forms.json
# Updated businesses\tax-act\license.json
# Updated businesses\tax-act\payments.json
# Updated businesses\tax-act\reports.json
# Updated businesses\tax-act\tax-rates.json
# Updated businesses\tnc\apply.json
# Updated businesses\tnc\contacts.json
# Updated businesses\tnc\faq.json
# Updated businesses\tnc\homepage.json
# Updated businesses\tnc\insurance.json
# Updated businesses\tnc\renew.json
# Updated businesses\tnc\screening.json
# Updated businesses\tnc\vehicle-req.json
# Updated licenses-ids\cdl\applying.json
# Updated licenses-ids\cdl\class.json
# Updated licenses-ids\cdl\clinic.json
# Updated licenses-ids\cdl\dach.json
# Updated licenses-ids\cdl\disqual.json
# Updated licenses-ids\cdl\docs.json
# Updated licenses-ids\cdl\eligibility.json
# Updated licenses-ids\cdl\hazmat.json
# Updated licenses-ids\cdl\homepage.json
# Updated licenses-ids\cdl\locations.json
# Updated licenses-ids\cdl\manual.json
# Updated licenses-ids\cdl\medical-faqs.json
# Updated licenses-ids\cdl\medical.json
# Updated licenses-ids\cdl\permit.json
# Updated licenses-ids\cdl\renew-driver.json
# Updated licenses-ids\cdl\replacement.json
# Updated licenses-ids\cdl\road-test.json
# Updated licenses-ids\cdl\spe.json
# Updated licenses-ids\cdl\test.json
# Updated licenses-ids\cdl\third-test.json
# Updated licenses-ids\cdl\training-schools.json
# Updated licenses-ids\cdl\troops-trucks.json
# Updated licenses-ids\cdl\vccs-schools.json
# Updated licenses-ids\cdl\vccs.json
# Updated licenses-ids\disability\apply-assist.json
# Updated licenses-ids\disability\descrip.json
# Updated licenses-ids\disability\hearing-assist.json
# Updated licenses-ids\disability\homepage.json
# Updated licenses-ids\disability\plates-assist.json
# Updated licenses-ids\disability\renewal.json
# Updated licenses-ids\disability\rights.json
# Updated licenses-ids\disability\visit-assist.json
# Updated licenses-ids\disability\visor-alert.json
# Updated licenses-ids\exams\homepage.json
# Updated licenses-ids\exams\know-exam.json
# Updated licenses-ids\exams\manual-es.json
# Updated licenses-ids\exams\manual.json
# Updated licenses-ids\exams\practice-exam.json
# Updated licenses-ids\exams\road-skills-test.json
# Updated licenses-ids\id-cards\adult-id.json
# Updated licenses-ids\id-cards\child-id.json
# Updated licenses-ids\id-cards\get-id.json
# Updated licenses-ids\id-cards\homepage.json
# Updated licenses-ids\id-cards\legal-presence.json
# Updated licenses-ids\id-cards\license-exchange.json
# Updated licenses-ids\id-cards\photo-id.json
# Updated licenses-ids\id-cards\privilege.json
# Updated licenses-ids\id-cards\renewing-identification-card.json
# Updated licenses-ids\id-cards\replacement-id.json
# Updated licenses-ids\id-cards\services.json
# Updated licenses-ids\id-cards\ssn-replace.json
# Updated licenses-ids\id-cards\vet-id.json
# Updated licenses-ids\improvement\assess.json
# Updated licenses-ids\improvement\homepage.json
# Updated licenses-ids\improvement\over-18.json
# Updated licenses-ids\improvement\points-3.json
# Updated licenses-ids\improvement\points-4.json
# Updated licenses-ids\improvement\points-6.json
# Updated licenses-ids\improvement\points.json
# Updated licenses-ids\improvement\system.json
# Updated licenses-ids\improvement\under-18.json
# Updated licenses-ids\learners\90min.json
# Updated licenses-ids\learners\apply.json
# Updated licenses-ids\learners\ed-reqs.json
# Updated licenses-ids\learners\homepage.json
# Updated licenses-ids\learners\homeschool.json
# Updated licenses-ids\learners\remote-test.json
# Updated licenses-ids\learners\restrictions.json
# Updated licenses-ids\learners\teen-faq.json
# Updated licenses-ids\learners\teen.json
# Updated licenses-ids\license\applying.json
# Updated licenses-ids\license\counterfeit.json
# Updated licenses-ids\license\disguises.json
# Updated licenses-ids\license\eligibility.json
# Updated licenses-ids\license\evve-info.json
# Updated licenses-ids\license\evve.json
# Updated licenses-ids\license\exchange-foreign-dl.json
# Updated licenses-ids\license\homepage.json
# Updated licenses-ids\license\identity-theft.json
# Updated licenses-ids\license\newlook2023.json
# Updated licenses-ids\license\tracking.json
# Updated licenses-ids\license-extension\contractor.json
# Updated licenses-ids\license-extension\diplomat.json
# Updated licenses-ids\license-extension\homepage.json
# Updated licenses-ids\license-extension\military.json
# Updated licenses-ids\mature\homepage.json
# Updated licenses-ids\military\faq.json
# Updated licenses-ids\military\homepage.json
# Updated licenses-ids\motorcycle\getting.json
# Updated licenses-ids\motorcycle\homepage.json
# Updated licenses-ids\motorcycle\knowledge-exam.json
# Updated licenses-ids\motorcycle\learners.json
# Updated licenses-ids\motorcycle\operate.json
# Updated licenses-ids\motorcycle\out-state.json
# Updated licenses-ids\motorcycle\skills-test.json
# Updated licenses-ids\organ-donation\homepage.json
# Updated licenses-ids\payment-plan-program\homepage.json
# Updated licenses-ids\real-id\faq.json
# Updated licenses-ids\real-id\homepage.json
# Updated licenses-ids\training\applying.json
# Updated licenses-ids\training\class-a-third-list.json
# Updated licenses-ids\training\descrip.json
# Updated licenses-ids\training\driver-training-schools.json
# Updated licenses-ids\training\dts-become.json
# Updated licenses-ids\training\dtsmanual-license.json
# Updated licenses-ids\training\dtsonline.json
# Updated licenses-ids\training\entry-level.json
# Updated licenses-ids\training\escrt.json
# Updated licenses-ids\training\faqs-drv.json
# Updated licenses-ids\training\faqs-schools-training-driver-privilege-card-dpc.json
# Updated licenses-ids\training\faqs-veh.json
# Updated licenses-ids\training\faqs.json
# Updated licenses-ids\training\homepage.json
# Updated licenses-ids\training\in-person-manual.json
# Updated licenses-ids\training\manual-vendors.json
# Updated licenses-ids\training\providers.json
# Updated licenses-ids\training\third-a-apply.json
# Updated licenses-ids\training\third-a-exam.json
# Updated licenses-ids\training\third-a-test.json
# Updated licenses-ids\training\three-exam-failures.json
# Updated licenses-ids\training\trainer.json
# Updated licenses-ids\training\training-sites.json
# Updated node\6896\6896.json
# Updated records\emergency-contact\homepage.json
# Updated records\family-deceased\cancel.json
# Updated records\family-deceased\clear.json
# Updated records\family-deceased\homepage.json
# Updated records\family-deceased\transfer-ownership.json
# Updated records\family-deceased\transfer-registration.json
# Updated records\foia\homepage.json
# Updated records\non-governmental-access\homepage.json
# Updated records\personal-information-updates\homepage.json
# Updated records\ppi\homepage.json
# Updated records\release\homepage.json
# Updated records\request-driver-vehicle-record\homepage.json
# Updated records\request-police-crash-report\homepage.json
# Updated records\vital\acceptable-records.json
# Updated records\vital\homepage.json
# Updated records\vital\record-certificates.json
# Updated records\voluntary\homepage.json
# Updated records\vote\homepage.json
# Updated safety\crash-data\homepage.json
# Updated safety\crash-data\house-legis-district-crash-data.json
# Updated safety\crash-data\senate-legis-district-crash-data.json
# Updated safety\crash-data\traffic-records-electronic-data-system.json
# Updated safety\crash-data\traffic-records-management.json
# Updated safety\grants-management\homepage.json
# Updated safety\grants-management\motorcycle-safety-funding.json
# Updated safety\grants-management\occupant-protection-funding.json
# Updated safety\grants-management\pedestrian-safety-funding.json
# Updated safety\grants-management\reduce-aggresive-driving-funding.json
# Updated safety\grants-management\reduce-impaired-driving-funding.json
# Updated safety\grants-management\roadway-safety-funding.json
# Updated safety\grants-management\safety-grant-faqs.json
# Updated safety\grants-management\traffic-record-funding.json
# Updated safety\resources\committees.json
# Updated safety\resources\contacts-bristol.json
# Updated safety\resources\contacts-fairfax.json
# Updated safety\resources\contacts-portsmouth.json
# Updated safety\resources\contacts-richmond.json
# Updated safety\resources\contacts-roanoke.json
# Updated safety\resources\contacts-staunton.json
# Updated safety\resources\forms.json
# Updated safety\resources\homepage.json
# Updated safety\resources\other-contacts.json
# Updated safety\resources\presentations.json
# Updated safety\resources\safety-contacts.json
# Updated safety\resources\summit21.json
# Updated safety\resources\summit22.json
# Updated safety\resources\tire-safety-tips.json
# Updated safety\resources\videos.json
# Updated vehicles\buy-sell\homepage.json
# Updated vehicles\ez-pass\homepage.json
# Updated vehicles\ez-pass\locations.json
# Updated vehicles\general\consumer.json
# Updated vehicles\general\crash-dmv.json
# Updated vehicles\general\homepage.json
# Updated vehicles\general\leased.json
# Updated vehicles\general\lemon-law.json
# Updated vehicles\general\mobile.json
# Updated vehicles\general\odometer.json
# Updated vehicles\general\pets-cars.json
# Updated vehicles\general\recalls.json
# Updated vehicles\general\used-car-tips.json
# Updated vehicles\insurance-requirements\homepage.json
# Updated vehicles\registration\alternative-vehicles.json
# Updated vehicles\registration\antique.json
# Updated vehicles\registration\color-codes.json
# Updated vehicles\registration\denials.json
# Updated vehicles\registration\emissions.json
# Updated vehicles\registration\enotification-info.json
# Updated vehicles\registration\enotification-policy.json
# Updated vehicles\registration\exemp-disc-chart.json
# Updated vehicles\registration\farm.json
# Updated vehicles\registration\first-reg.json
# Updated vehicles\registration\homepage.json
# Updated vehicles\registration\lvrp.json
# Updated vehicles\registration\mail-renew.json
# Updated vehicles\registration\moped.json
# Updated vehicles\registration\sample-card.json
# Updated vehicles\registration\state-owned-vehicles.json
# Updated vehicles\registration\stop-register.json
# Updated vehicles\registration\surplus.json
# Updated vehicles\registration\temp-permit.json
# Updated vehicles\registration\title-mail-reg-only.json
# Updated vehicles\registration\tow-truck-reg.json
# Updated vehicles\registration\trailer.json
# Updated vehicles\taxes-fees\homepage.json
# Updated vehicles\taxes-fees\sales-and-use-tax-refunds.json
# Updated vehicles\taxes-fees\sut.json
# Updated vehicles\title\all-terrain-vehicles.json
# Updated vehicles\title\app-dropoff-service.json
# Updated vehicles\title\designative-beneficiary.json
# Updated vehicles\title\disabled-vet-tax-exemption.json
# Updated vehicles\title\electric.json
# Updated vehicles\title\etitle.json
# Updated vehicles\title\homepage.json
# Updated vehicles\title\liens.json
# Updated vehicles\title\mail.json
# Updated vehicles\title\motor-home.json
# Updated vehicles\title\original-electronic.json
# Updated vehicles\title\reconstructed.json
# Updated vehicles\title\replacement.json
# Updated vehicles\title\repossessed.json
# Updated vehicles\title\sal-veh-law-req.json
# Updated vehicles\title\substitute.json
# Updated vehicles\title\trailer-plate.json
# Operation completed
